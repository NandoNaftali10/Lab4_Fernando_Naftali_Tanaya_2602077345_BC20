# %%
import numpy as np

def my_bisection(f, a, b, tol):
  if np.sign(f(a)) == np.sign(f(b)):
    raise Exception(
        "The scalars a and b do not bound a root")
  
  m = (a + b) / 2

  if np.abs(f(m)) < tol:
    return m
  elif np.sign(f(a)) == np.sign(f(m)):
    return my_bisection(f, m, b, tol)
  elif np.sign(f(b)) == np.sign(f(m)):
    return my_bisection(f, a, m, tol)

# %%
f = lambda x: x**2 - 2

r1 = my_bisection(f, 0, 2, 0.1)
print("r1 =", r1)
r01 = my_bisection(f, 0, 2, 0.01)
print("r01 =", r01)

print("f(r1) =", f(r1))
print("f(r01) =", f(r01))
# Out:
# r1 = 1.4375
# r01 = 1.4140625
# f(r1) = 0.06640625
# f(r01) = -0.00042724609375

# %%
my_bisection(f, 0, 1, 00.1)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-8-a3338286c62e> in <cell line: 1>()
# ----> 1 my_bisection(f, 0, 1, 00.1)
#
# <ipython-input-1-5c8f4784ba4a> in my_bisection(f, a, b, tol)
#       3 def my_bisection(f, a, b, tol):
#       4   if np.sign(f(a)) == np.sign(f(b)):
# ----> 5     raise Exception(
#       6         "The scalars a and b do not bound a root")
#       7
#
# Exception: The scalars a and b do not bound a root
